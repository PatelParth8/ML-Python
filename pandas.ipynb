# %%
import pandas as pd

# %% [markdown]
# New File -> pokemon_data.csv

# %%
df = pd.read_csv("/Users/parth/Desktop/pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#Top 5 records
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#Reading Data From DataFrame
df['HP'] #Single Column
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
df[['HP','Attack']] #multiple Column
# Out:
#      HP  Attack
# 0    45      49
# 1    60      62
# 2    80      82
# 3    80     100
# 4    39      52
# ..   ..     ...
# 795  50     100
# 796  50     160
# 797  80     110
# 798  80     160
# 799  80     110
#
# [800 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name', 'Type 1', 'HP']] #Print Defined Columns
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
df.iloc[5]
# Out:
# #                      5
# Name          Charmeleon
# Type 1              Fire
# Type 2               NaN
# HP                    58
# Attack                64
# Defense               58
# Sp. Atk               80
# Sp. Def               65
# Speed                 80
# Generation             1
# Legendary          False
# Name: 5, dtype: object

# %%
df.iloc[5][2]
# Out:
# /var/folders/qp/4yml_rxn78x4648rj5mzzmk80000gn/T/ipykernel_17176/2986200320.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[5][2]
# 'Fire'

# %%
df.sort_values(['HP', 'Name'], ascending=[1,1])
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# ...

# %%
#Changes in Data Frame
df['Total'] = df['Attack']+df['Defense']+df['Generation'] #Add New Column
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False     99
# ...

# %%
#Drop the Columns
df = df.drop(columns=['Total', 'Attack'])
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Defense  Sp. Atk  \
# 0      1              Bulbasaur    Grass  Poison  45       49       65
# 1      2                Ivysaur    Grass  Poison  60       63       80
# 2      3               Venusaur    Grass  Poison  80       83      100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80      123      122
# 4      4             Charmander     Fire     NaN  39       43       60
# ..   ...                    ...      ...     ...  ..      ...      ...
# 795  719                Diancie     Rock   Fairy  50      150      100
# 796  719    DiancieMega Diancie     Rock   Fairy  50      110      160
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80       60      150
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80       60      170
# 799  721              Volcanion     Fire   Water  80      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
#defence>50 & attack<100
df[(df['Defense'] > 50) & (df['Sp. Atk'] < 100)]
# Out:
#        #                 Name  Type 1  Type 2   HP  Defense  Sp. Atk  Sp. Def  \
# 1      2              Ivysaur   Grass  Poison   60       63       80       80
# 5      5           Charmeleon    Fire     NaN   58       58       80       65
# 9      7             Squirtle   Water     NaN   44       65       50       64
# 10     8            Wartortle   Water     NaN   59       80       65       80
# 11     9            Blastoise   Water     NaN   79      100       85      105
# ..   ...                  ...     ...     ...  ...      ...      ...      ...
# 787  711  GourgeistSuper Size   Ghost   Grass   85      122       58       75
# 788  712             Bergmite     Ice     NaN   55       85       32       35
# 789  713              Avalugg     Ice     NaN   95      184       44       46
# 791  715              Noivern  Flying  Dragon   85       80       97       80
# 794  718     Zygarde50% Forme  Dragon  Ground  108      121       81       95
#
# ...

# %%
df.describe()
# Out:
#                 #          HP     Defense     Sp. Atk     Sp. Def       Speed  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   73.842500   72.820000   71.902500   68.277500
# std    208.343798   25.534669   31.183501   32.722294   27.828916   29.060474
# min      1.000000    1.000000    5.000000   10.000000   20.000000    5.000000
# 25%    184.750000   50.000000   50.000000   49.750000   50.000000   45.000000
# 50%    364.500000   65.000000   70.000000   65.000000   70.000000   65.000000
# 75%    539.250000   80.000000   90.000000   95.000000   90.000000   90.000000
# max    721.000000  255.000000  230.000000  194.000000  230.000000  180.000000
#
#        Generation
# count   800.00000
# mean      3.32375
# std       1.66129
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max       6.00000

# %%
#New File
#parth.csv

# %%
df1 = pd.read_csv("/Users/parth/Documents/untitled folder/ML in Python/clg/parth.csv")
df1
# Out:
#    ID     Name  Salary         DOB  Age
# 0   1    Parth   98000  08/09/2002   22
# 1   2      Raj   68000  29/12/2002   22
# 2   3  Harshil   58000  08/02/2000   24
# 3   4    Aryan   46000  24/11/2004   20
# 4   5    Utsav   50000  20/04/2001   23

# %%
df1.head()
# Out:
#    ID     Name  Salary         DOB  Age
# 0   1    Parth   98000  08/09/2002   22
# 1   2      Raj   68000  29/12/2002   22
# 2   3  Harshil   58000  08/02/2000   24
# 3   4    Aryan   46000  24/11/2004   20
# 4   5    Utsav   50000  20/04/2001   23

# %%
df1.tail()
# Out:
#    ID     Name  Salary         DOB  Age
# 0   1    Parth   98000  08/09/2002   22
# 1   2      Raj   68000  29/12/2002   22
# 2   3  Harshil   58000  08/02/2000   24
# 3   4    Aryan   46000  24/11/2004   20
# 4   5    Utsav   50000  20/04/2001   23

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      5 non-null      int64
#  1   Name    5 non-null      object
#  2   Salary  5 non-null      int64
#  3   DOB     5 non-null      object
#  4   Age     5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
df1.describe()
# Out:
#              ID        Salary       Age
# count  5.000000      5.000000   5.00000
# mean   3.000000  64000.000000  22.20000
# std    1.581139  20784.609691   1.48324
# min    1.000000  46000.000000  20.00000
# 25%    2.000000  50000.000000  22.00000
# 50%    3.000000  58000.000000  22.00000
# 75%    4.000000  68000.000000  23.00000
# max    5.000000  98000.000000  24.00000

# %%
df1['increment'] = [12000,10000,8000,6000,4000]
df1
# Out:
#    ID     Name  Salary         DOB  Age  increment
# 0   1    Parth   98000  08/09/2002   22      12000
# 1   2      Raj   68000  29/12/2002   22      10000
# 2   3  Harshil   58000  08/02/2000   24       8000
# 3   4    Aryan   46000  24/11/2004   20       6000
# 4   5    Utsav   50000  20/04/2001   23       4000

# %%
df1['Gross Salary'] = df1['Salary'] + df1['increment']
df1
# Out:
#    ID     Name  Salary         DOB  Age  increment  Gross Salary
# 0   1    Parth   98000  08/09/2002   22      12000        110000
# 1   2      Raj   68000  29/12/2002   22      10000         78000
# 2   3  Harshil   58000  08/02/2000   24       8000         66000
# 3   4    Aryan   46000  24/11/2004   20       6000         52000
# 4   5    Utsav   50000  20/04/2001   23       4000         54000

# %% [markdown]
# New File -> data.csv

# %%
df2 = pd.read_csv("/Users/parth/Documents/untitled folder/ML in Python/clg/data.csv")
df2
# Out:
#     Enrollement_No Name  Python  Java    SE
# 0                1    A    89.0  97.0  76.0
# 1                2    B    79.0  78.0  86.0
# 2                3    C    49.0  49.0  47.0
# 3                4    D    94.0  57.0  69.0
# 4                5    E    69.0  69.0  77.0
# 5                6    F    49.0  76.0  58.0
# 6                7    G    65.0   NaN  57.0
# 7                8    H    70.0  94.0  99.0
# 8                9    I    65.0  96.0  76.0
# 9               10    J    78.0  56.0  89.0
# 10               6    F    76.0  46.0  57.0
# 11              12    K     NaN  87.0  87.0
# 12              13    L    45.0  92.0   NaN
# 13               5    E    39.0  65.0  57.0
# 14              15    M    65.0  46.0  57.0
# 15              16    N    87.0  97.0  65.0
# 16               4    D    93.0  36.0  86.0
# 17              18    O    69.0  76.0  46.0
# 18               3    C    67.0  56.0  55.0
# 19              20    P    71.0  47.0   NaN

# %%
#Print last 7 records
print(df2.tail(7))
# Out:
#     Enrollement_No Name  Python  Java    SE
# 13               5    E    39.0  65.0  57.0
# 14              15    M    65.0  46.0  57.0
# 15              16    N    87.0  97.0  65.0
# 16               4    D    93.0  36.0  86.0
# 17              18    O    69.0  76.0  46.0
# 18               3    C    67.0  56.0  55.0
# 19              20    P    71.0  47.0   NaN

# %%
#print top 5 records
print(df2.head(5))
# Out:
#    Enrollement_No Name  Python  Java    SE
# 0               1    A    89.0  97.0  76.0
# 1               2    B    79.0  78.0  86.0
# 2               3    C    49.0  49.0  47.0
# 3               4    D    94.0  57.0  69.0
# 4               5    E    69.0  69.0  77.0

# %%
df2['Java'].max()
# Out:
# 97.0

# %%
df2.iloc[[df2['Java'].idxmax()]] #find maximum marks of Java
# Out:
#    Enrollement_No Name  Python  Java    SE
# 0               1    A    89.0  97.0  76.0

# %%
df2.iloc[[df2['Python'].idxmin()]] #find minimum marks of Python
# Out:
#     Enrollement_No Name  Python  Java    SE
# 13               5    E    39.0  65.0  57.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Enrollement_No  20 non-null     int64
#  1   Name            20 non-null     object
#  2   Python          19 non-null     float64
#  3   Java            19 non-null     float64
#  4   SE              18 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 928.0+ bytes

# %%
df2.describe()
# Out:
#        Enrollement_No     Python       Java         SE
# count       20.000000  19.000000  19.000000  18.000000
# mean         8.350000  69.421053  69.473684  69.111111
# std          5.593935  15.784366  20.383458  15.877801
# min          1.000000  39.000000  36.000000  46.000000
# 25%          4.000000  65.000000  52.500000  57.000000
# 50%          6.500000  69.000000  69.000000  67.000000
# 75%         12.250000  78.500000  89.500000  83.750000
# max         20.000000  94.000000  97.000000  99.000000

# %%
df2[['Python', 'Java', 'SE']].mean()
# Out:
# Python    69.421053
# Java      69.473684
# SE        69.111111
# dtype: float64

# %%
df2['Total'] = df2['Python'] + df2['Java'] + df2['SE'] #add new column
df2
# Out:
#     Enrollement_No Name  Python  Java    SE  Total
# 0                1    A    89.0  97.0  76.0  262.0
# 1                2    B    79.0  78.0  86.0  243.0
# 2                3    C    49.0  49.0  47.0  145.0
# 3                4    D    94.0  57.0  69.0  220.0
# 4                5    E    69.0  69.0  77.0  215.0
# 5                6    F    49.0  76.0  58.0  183.0
# 6                7    G    65.0   NaN  57.0    NaN
# 7                8    H    70.0  94.0  99.0  263.0
# 8                9    I    65.0  96.0  76.0  237.0
# 9               10    J    78.0  56.0  89.0  223.0
# 10               6    F    76.0  46.0  57.0  179.0
# 11              12    K     NaN  87.0  87.0    NaN
# 12              13    L    45.0  92.0   NaN    NaN
# 13               5    E    39.0  65.0  57.0  161.0
# 14              15    M    65.0  46.0  57.0  168.0
# 15              16    N    87.0  97.0  65.0  249.0
# 16               4    D    93.0  36.0  86.0  215.0
# ...

# %%
df2['Total'].sort_values()
# Out:
# 2     145.0
# 13    161.0
# 14    168.0
# 18    178.0
# 10    179.0
# 5     183.0
# 17    191.0
# 4     215.0
# 16    215.0
# 3     220.0
# 9     223.0
# 8     237.0
# 1     243.0
# 15    249.0
# 0     262.0
# 7     263.0
# 6       NaN
# 11      NaN
# 12      NaN
# 19      NaN
# Name: Total, dtype: float64

# %%
df2.isnull()
# Out:
#     Enrollement_No   Name  Python   Java     SE  Total
# 0            False  False   False  False  False  False
# 1            False  False   False  False  False  False
# 2            False  False   False  False  False  False
# 3            False  False   False  False  False  False
# 4            False  False   False  False  False  False
# 5            False  False   False  False  False  False
# 6            False  False   False   True  False   True
# 7            False  False   False  False  False  False
# 8            False  False   False  False  False  False
# 9            False  False   False  False  False  False
# 10           False  False   False  False  False  False
# 11           False  False    True  False  False   True
# 12           False  False   False  False   True   True
# 13           False  False   False  False  False  False
# 14           False  False   False  False  False  False
# 15           False  False   False  False  False  False
# ...

# %%
a = df2['Java'].mean()
a
# Out:
# 69.47368421052632

# %%
a1 = df2['Java'].fillna(value=a,inplace=True)
df2
# Out:
#     Enrollement_No Name  Python       Java    SE  Total
# 0                1    A    89.0  97.000000  76.0  262.0
# 1                2    B    79.0  78.000000  86.0  243.0
# 2                3    C    49.0  49.000000  47.0  145.0
# 3                4    D    94.0  57.000000  69.0  220.0
# 4                5    E    69.0  69.000000  77.0  215.0
# 5                6    F    49.0  76.000000  58.0  183.0
# 6                7    G    65.0  69.473684  57.0    NaN
# 7                8    H    70.0  94.000000  99.0  263.0
# 8                9    I    65.0  96.000000  76.0  237.0
# 9               10    J    78.0  56.000000  89.0  223.0
# 10               6    F    76.0  46.000000  57.0  179.0
# 11              12    K     NaN  87.000000  87.0    NaN
# 12              13    L    45.0  92.000000   NaN    NaN
# 13               5    E    39.0  65.000000  57.0  161.0
# 14              15    M    65.0  46.000000  57.0  168.0
# 15              16    N    87.0  97.000000  65.0  249.0
# ...

# %%
b = df2['Python'].mean()
b
# Out:
# 69.42105263157895

# %%
b1 = df2['Python'].fillna(value=b, inplace=True)
df2
# Out:
#     Enrollement_No Name     Python       Java    SE  Total
# 0                1    A  89.000000  97.000000  76.0  262.0
# 1                2    B  79.000000  78.000000  86.0  243.0
# 2                3    C  49.000000  49.000000  47.0  145.0
# 3                4    D  94.000000  57.000000  69.0  220.0
# 4                5    E  69.000000  69.000000  77.0  215.0
# 5                6    F  49.000000  76.000000  58.0  183.0
# 6                7    G  65.000000  69.473684  57.0    NaN
# 7                8    H  70.000000  94.000000  99.0  263.0
# 8                9    I  65.000000  96.000000  76.0  237.0
# 9               10    J  78.000000  56.000000  89.0  223.0
# 10               6    F  76.000000  46.000000  57.0  179.0
# 11              12    K  69.421053  87.000000  87.0    NaN
# 12              13    L  45.000000  92.000000   NaN    NaN
# 13               5    E  39.000000  65.000000  57.0  161.0
# 14              15    M  65.000000  46.000000  57.0  168.0
# ...

# %%
c = df2['SE'].mean()
c
# Out:
# 69.11111111111111

# %%
c1 = df2['SE'].fillna(value=c, inplace=True)
c1

# %%
df2
# Out:
#     Enrollement_No Name     Python       Java         SE  Total
# 0                1    A  89.000000  97.000000  76.000000  262.0
# 1                2    B  79.000000  78.000000  86.000000  243.0
# 2                3    C  49.000000  49.000000  47.000000  145.0
# 3                4    D  94.000000  57.000000  69.000000  220.0
# 4                5    E  69.000000  69.000000  77.000000  215.0
# 5                6    F  49.000000  76.000000  58.000000  183.0
# 6                7    G  65.000000  69.473684  57.000000    NaN
# 7                8    H  70.000000  94.000000  99.000000  263.0
# 8                9    I  65.000000  96.000000  76.000000  237.0
# 9               10    J  78.000000  56.000000  89.000000  223.0
# 10               6    F  76.000000  46.000000  57.000000  179.0
# 11              12    K  69.421053  87.000000  87.000000    NaN
# 12              13    L  45.000000  92.000000  69.111111    NaN
# 13               5    E  39.000000  65.000000  57.000000  161.0
# ...

# %%
df2['Total'].drop
# Out:
# <bound method Series.drop of 0     262.0
# 1     243.0
# 2     145.0
# 3     220.0
# 4     215.0
# 5     183.0
# 6       NaN
# 7     263.0
# 8     237.0
# 9     223.0
# 10    179.0
# 11      NaN
# 12      NaN
# 13    161.0
# 14    168.0
# 15    249.0
# 16    215.0
# 17    191.0
# 18    178.0
# 19      NaN
# Name: Total, dtype: float64>

# %%
df2['Total'] = df2['Python'] + df2['Java'] + df2['SE']#add new column
df2
# Out:
#     Enrollement_No Name     Python       Java         SE       Total
# 0                1    A  89.000000  97.000000  76.000000  262.000000
# 1                2    B  79.000000  78.000000  86.000000  243.000000
# 2                3    C  49.000000  49.000000  47.000000  145.000000
# 3                4    D  94.000000  57.000000  69.000000  220.000000
# 4                5    E  69.000000  69.000000  77.000000  215.000000
# 5                6    F  49.000000  76.000000  58.000000  183.000000
# 6                7    G  65.000000  69.473684  57.000000  191.473684
# 7                8    H  70.000000  94.000000  99.000000  263.000000
# 8                9    I  65.000000  96.000000  76.000000  237.000000
# 9               10    J  78.000000  56.000000  89.000000  223.000000
# 10               6    F  76.000000  46.000000  57.000000  179.000000
# 11              12    K  69.421053  87.000000  87.000000  243.421053
# 12              13    L  45.000000  92.000000  69.111111  206.111111
# ...

# %% [markdown]
# #New csv file -> employees.csv

# %%
df3 = pd.read_csv("/Users/parth/Documents/untitled folder/ML in Python/clg/employees.csv")
df3
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df3.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df3['Team'].value_counts() #to count the number values
# Out:
# Team
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: count, dtype: int64

# %%
df3.shape #count rows and columns
# Out:
# (1000, 8)

# %%
r,c = df3.shape #count rows and columns
r,c
# Out:
# (1000, 8)

# %%
df3.iloc[10:15] #print records between 10-15
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
#
#    Senior Management             Team
# 10              True              NaN
# 11              True            Legal
# 12              True  Human Resources
# 13             False            Sales
# 14              True          Finance

# %%
df3.isnull() #to find null records
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# ...

# %%
df3.notnull() #to find not null records
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0          True    True        True             True    True     True
# 1          True    True        True             True    True     True
# 2          True    True        True             True    True     True
# 3          True    True        True             True    True     True
# 4          True    True        True             True    True     True
# ..          ...     ...         ...              ...     ...      ...
# 995        True   False        True             True    True     True
# 996        True    True        True             True    True     True
# 997        True    True        True             True    True     True
# 998        True    True        True             True    True     True
# 999        True    True        True             True    True     True
#
#      Senior Management   Team
# 0                 True   True
# 1                 True  False
# 2                 True   True
# ...

# %%
df3.drop_duplicates() #to drop duplicates records
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df3.columns #to print columns names
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df3['Team'] #to print particular column records
# Out:
# 0                 Marketing
# 1                       NaN
# 2                   Finance
# 3                   Finance
# 4           Client Services
#                ...
# 995            Distribution
# 996                 Finance
# 997                 Product
# 998    Business Development
# 999                   Sales
# Name: Team, Length: 1000, dtype: object

# %%
df3[['First Name', 'Team', 'Gender']] #to print the particular columns
# Out:
#     First Name                  Team  Gender
# 0      Douglas             Marketing    Male
# 1       Thomas                   NaN    Male
# 2        Maria               Finance  Female
# 3        Jerry               Finance    Male
# 4        Larry       Client Services    Male
# ..         ...                   ...     ...
# 995      Henry          Distribution     NaN
# 996    Phillip               Finance    Male
# 997    Russell               Product    Male
# 998      Larry  Business Development    Male
# 999     Albert                 Sales    Male
#
# [1000 rows x 3 columns]

# %%
df3[df3['Salary']>50000]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df3.dropna()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
df3['Increment'] = (df3['Salary']*df3['Bonus %'])/100 #add new column
df3
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team    Increment
# 0                True             Marketing   6758.04060
# ...

# %%
df3['Gross Salary'] = df3['Increment'] + df3['Salary']
df3
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team    Increment  Gross Salary
# 0                True             Marketing   6758.04060  104066.04060
# ...

# %%
df3.iloc[[df3['Salary'].idxmax()]] #find maximum salary
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
#
#     Senior Management     Team    Increment  Gross Salary
# 644             False  Finance  28350.60096  178258.60096

# %%
a = df3.loc[df3['Gender'] == 'Male']
a
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas   Male  3/31/1996         6:53 AM   61933    4.170
# 3        Jerry   Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry   Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis   Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip   Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team    Increment  Gross Salary
# 0                True             Marketing   6758.04060  104066.04060
# ...

# %%
df3.iloc[[a['Salary'].idxmax()]]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 981      James   Male  1/15/1993         5:19 PM  148985    19.28
#
#     Senior Management   Team  Increment  Gross Salary
# 981             False  Legal  28724.308    177709.308
